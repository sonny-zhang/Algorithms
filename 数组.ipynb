# %% [markdown]
# # 数组
#
# **数组：** 数组（Array）是一种线性表(Linear List)数据结构。它用一组连 续的内存空间，来存储一组具有相同类型的数据。
# **线性表：** 线性表就是数据排成像一条线一样的结构。每个线性表上的数据最多只有前和后两个方向。数组、队列、链表、栈等。
# ![image.png](attachment:image.png)
#
# **非线性表：** 与线性表相反。二叉树、堆、图等。
# ![image.png](attachment:image.png)
