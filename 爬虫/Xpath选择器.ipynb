# %% [markdown]
# ## Xpath选择器
# - 父节点：一个人只能有一个父亲
# - 子节点：一个父亲会有多个儿子
# - 同级节点：一个人会有多个兄弟
# - 祖先节点：一个人会有多个祖先(父亲、爷爷、姥爷)
# - 后代节点：一个人会有很多后代(儿子、孙子、曾孙子)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
